# %% [markdown]
# ### Todo
# 0. ajouté deux features : durée moyenne de séjour, et l'anticipation   (x)
# 0. ajouter les evenements
# 1. plusieurs modele J-27, J-21,J-14,J-7,J-3
# 1. ajouter le prix  de vente actuel de l'hotel sur booking
#
# 2. Scrpit d'entrainement par hotel : ajouter hotel en parametre ou boucle sur tous les hotels
# 3. Api: prediction à j-X avec une des infos pour afficher une courbe
#
# 4. mise à jour de l'APi annulation ( pas le client mystique)
#
# 5.definir pour un hotel la haute et la basse saison
# 6. budget avec ML
#
# 6- feature engeniring sur les annulation : analyser les articles de recherche
#   Ajouter les ponts  au jours feriés
